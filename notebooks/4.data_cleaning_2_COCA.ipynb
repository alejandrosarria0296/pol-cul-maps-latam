# %%
cd /Users/nte/Documents/Chicago\ PhD\ Projects/Political\ culture\ maps/1.ANALYSIS
# Out:
# [WinError 3] The system cannot find the path specified: '/Users/nte/Documents/Chicago\\ PhD\\ Projects/Political\\ culture\\ maps/1.ANALYSIS'
# c:\Users\asarr\Documents\Projects\pol_cul_maps_LA

# %% [markdown]
# !/usr/bin/env python coding: utf-8
# Culture Maps Project
#
# ## Author: Alejandro Sarria-Morales
# ## Created: July 2024
# ## Date(last modified): July 26th 2024
# ## Data storage:
#     ### Merges website's source data (from csv) and text data dictionary (from json) and saves it as a csv.
#     ### It allows to create different data frames filtering by the number of words (e.g., all websites with less than 3k)
# ## Working with the Corpus of Contemporary American English (COCA)
#
# ## Notebook index:
#     # 1. Libraries
#     # 2. Helper functions
#     # 3. Pipeline
#     # 4. Save data frame as csv

# %% [markdown]
# # 1. Libraries

# %%
# # 1. Libraries 

import pandas as pd
import json
import numpy as np

# %% [markdown]
# # 2. Helper functions

# %%
def creates_df(source_list, websites_text, max_words, full_data=False):
    '''
    Merges sources data and websites text data from dictionary (json) and creates a 
    pandas dataframe. 
    
    Inpputs:
        source_list: (list) websites urls
        websites_text: (dictionary) 
                    key - (int) id
                    value - (string) websites' texts 
        max_words: (int) creates cut off depending on the number of words per website
                    e.g., if checkpoing 1K => no website with more than 1K words enters
        full_data: (boolean) defines data output 
        
    Output:
        If argument full_data TRUE => returns the entire data frame with NAs in text cells that it did not append.
            => span_df (pandas data frame) 
        If argument full_data FALSE => returns the entire data frame with NAs in text cells that it did not append.
             => smaller_df (pandas data frame)
        Defalt is FALSE.
        
    '''
    coca_df = source_list
    
    coca_df['text'] = np.nan
    coca_df['id_string'] = coca_df['textID'].astype(str)

    c = 0
    for index, row in coca_df.iterrows():
        textid_value = row['id_string']
        if textid_value in websites_text:
            text = websites_text[textid_value]
            word_count = len(text.split())
            if word_count < max_words:
                c += 1
                coca_df.at[index, 'text'] = text

    if full_data:
        print("RETURNING FULL DATA FRAME")
        return coca_df
    else:
        print("RETURNING SMALL DATA FRAME. NO NAs.") 
        smaller_df = coca_df[coca_df['text'] != 'NA']
        print("Number of website's texts incuded in data frame:", c) 
        return smaller_df

# %%
def count_matches(source_list, websites_text):
    '''
    Inpputs:
        source_list: (list) websites urls
        websites_text: (dictionary) 
                    key - (int) id
                    value - (string) websites' texts 
    Output:
        c: (int) count of matches
    '''
    
    c = 0
    
    for index, row in source_list.iterrows():
        textid_value = row['id_string']
        if textid_value in websites_text:
            c = c + 1

    print("Number of matches: ids both in dicitonary and source:", c)

    return c

# %% [markdown]
# # 3. Pipeline

# %%
# Reading json 

json_file = r"../data/dict_coca_full.json"

with open(json_file, "r") as read_file:
    dict_text_websites = json.load(read_file)

# %%
# File path
file_path = '../data/sources_coca.csv'

# Read the CSV file into a pandas DataFrame
df_sources = pd.read_csv(file_path)

# %%
df_sources.columns
# Out:
# Index(['textID', '#words', 'year', 'genre', 'subgen', 'source', 'title'], dtype='object')

# %%
df_sources.shape
# Out:
# (248948, 7)

# %%
df = creates_df(df_sources, dict_text_websites, 1000, full_data=False)
# Out:
# RETURNING SMALL DATA FRAME. NO NAs.
# Number of website's texts incuded in data frame: 3121

# %%
df.shape
# Out:
# (223830, 9)

# %% [markdown]
# #### I was able to run the funciton and create an smaller data frame for websites with less than 1,000 words.

# %%
df_3k = creates_df(df_sources, dict_text_websites, 3000, full_data=False)
df.shape

# %%
df_5k = creates_df(df_sources, dict_text_websites, 5000, full_data=False)
df_5k.to_csv('../data/coca_full_text_5k_words.csv', index=False)
# Out:
# C:\Users\asarr\AppData\Local\Temp\ipykernel_87096\3966534095.py:36: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'ANDER-VANOCUR  Welcome to Business World . I 'm Sander Vanocur  and here 's what 's on this week 's agenda . voice-over The peace dividend  if it means more unemployment  less high technology research and corporate cutbacks  could it really turn out to be the peace deficit  Also  whatever happened to the 40-hour work week  Is the press of competition creating a generation of workaholics  Are too many people living to work instead of working to live  And the other side of the coin  tips to take back your life and get away from your desk . From New York  this week 's Business World guest  Allied and Federated Stores chief Allen Questrom . Can he reverse Campeau 's collapse  ANNOUNCER  From ABC News  this is Business World  with Sander Vanocur and Stephen Aug . Now from New York  here 's Sander Vanocur VANOCUR The peace dividend . It was almost unthinkable a year ago . Then a wave of democracy swept Eastern Europe - Poland  Hungary  Czechoslovakia           today . And the Soviet Union now looks like a far less threatening adversary . The outbreak of peace holds out the promise of huge budget savings . But as business editor Stephen Aug reports  this could be another case when the silver lining has a storm cloud  one which might just rain on a military parade . Pres. GEORGE BUSH  January 31 Tonight  I am announcing a major new step for a further reduction in U.S. and Soviet manpower in Central and Eastern Europe to 195000 on each side . STEPHEN AUG  ABC News  voice-over That may have been good for a round of applause on Capitol Hill  but at the Lo-Mar Corporation out in Sharonville  Ohio  where they make rear-view mirrors for Army trucks  reduced troop levels means fewer troop maneuvers . CHRIS ALBERS  President  Lo-Mar Corporation  Where a lot of our replacement business does come from is on those maneuvers  mirrors get damaged  so they come back to the motor pool and they have to replace them AUG voice-over And that means fewer            the President has this to say just last Tuesday . Pres. BUSH  March 13 And I 'm requesting the Congress to approve  by April 5th  a package of assistance of 800 million for these two countries  using funds from the defense budget AUG voice-over And so the rise to democracy in Nicaragua  the downfall of a dictator in Panama  took another few hundred million dollars from the defense budget . Back out in Sharonville they put it this way . LEE RICHARDSON  Employee  Lo-Mar Corporation  Well  it 's something terrible . It 's a shame it has to be that way . I 'm getting old . It 's pretty well time for me to retire AUG voice-over She 's one of the 65 workers still on the job at Lo-Mar . That 's down from 90 just a few years ago  and for them the so-called peace dividend is more of a peace deficit . Like many other small defense contractors  the folks at Lo-Mar are learning how to cope with less business - much less .           and the defense share of their business is down two- thirds . For the first time  they and other firms like them really have to sell . Mr. ALBERS  The thing that I think a lot of defense companies are going to realize  it 's not the type of thing that you can go out tomorrow and knock on somebody 's door and get a new contract . You may go out and knock on somebody 's door and get some promising leads  but it may take you a year to get that business AUG voice-over In Ohio alone  there are so many small business firms in Lo-Mar 's situation that Governor Richard Celeste convened a conference on economic transition to peace for the state 's small business defense contractors . Gov . RICHARD CELESTE  ( D  Ohio  I think we have to operate on the assumption that meaningful defense cuts will affect us here in Ohio  and as a consequence - as a state - we ought to really try to gear ourselves ...
# ' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   coca_df.at[index, 'text'] = text
# RETURNING SMALL DATA FRAME. NO NAs.
# Number of website's texts incuded in data frame: 195633

# %%
df_10k = creates_df(df_sources, dict_text_websites, 10000, full_data=False)
df_10k.to_csv('../data/coca_full_text_10k_words.csv', index=False)
# Out:
# C:\Users\asarr\AppData\Local\Temp\ipykernel_87096\3966534095.py:36: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'UGH-DOWNS  Good evening . I 'm Hugh Downs . BARBARA WALTERS  And I 'm Barbara Walters . And this is 20/20 ANNOUNCER From ABC News  around the world and into your home  the stories that touch your life . With Hugh Downs and Barbara Walters  this is 20/20 . Tonight  sleepwalking  it 's not what you think it is . Dr. CARLOS SCHENCK  Psychiatrist  It 's amazing . Superhuman strength . SANDY SEEKON  Sleepwalker  It 's like you 're a different person ANNOUNCER Not really conscious  but not really asleep . There 's potential for danger and bizarre behavior . Mel Abel knows . One night  he attacked his wife . HARRIET ABEL  Wife of Sleepwalker  And I jumped up and I said  " What in the devil are you doing  " MEL ABEL  Sleepwalker  I thought  " Oh  my God . I could have broke her neck and killed her . " ANNOUNCER  It has happened . John Stossel reports experts call sleepwalking " The           something happens to you  what would happen to your best friend  If you leave him everything  will he land in heaven or flounder in legal limbo  WILL BOLGER  Pet Owner  The animals are really victims . They really become victims themselves ANNOUNCER Something to think about  " Who Will Love My Pet  " Joe Giarranto . Address  Death Row . Ten years ago  he confessed to a brutal double murder . JOE GIARRATANO  Death Row Inmate  You know  I was scared . I felt that I was evil ANNOUNCER Did he do it  That 's the question  after his total transformation . Lynn Sherr with a mysterious case and a puzzling personality . Joe Giarratano  " Is He a Killer  " Those stories tonight  January 12  1990 . Is He a Killer  DOWNS  A convicted killer proclaims he 's innocent . How many times have you heard that story  What 's different about Joe Giarratano is how he reached that conclusion . It was a journey of self- discovery           led to a startling revelation WALTERS Well  this is a man who says that the best days of his life have been his years on Death Row . This is a man who is so personable now that you wonder how he could have been found guilty of such a horrible double murder . Lynn Sherr has the story of Joe Giarratano and his growing number of friends and supporters . You watch and listen and then ask yourself  " Is He a Killer  " JOE GIARRATANO  Death Row Inmate  I 've lived more here on Death Row and have been happier here on Death Row than I 've ever been in my life . I did n't have a life before this . I was - I did n't know anything beyond sticking a needle in my arm and getting drunk . LYNN SHERR  voice-over It is a strange place to begin your life  in a six-by nine-foot cell on Death Row at Mecklenburg Correctional Center in Virginia . But for Joe Giarratano  33  the ten years he 's spent waiting           self-discovery . He was convicted of rape and a double murder  but in the process of recapturing his own sense of worth  he is also making a case for his own innocence . Joe 's story begins here in Norfolk  Virginia where he was working as a fisherman in 1979 . He 'd fled an abusive family situation in Florida and at 22 was already a heavy user of alcohol and drugs . interviewing If I had run into you during that period of your life  what would I have seen  Mr. GIARRATANO  Just somebody who was n't in touch with anything  just stayed to himself  set off in a corner . Just did n't talk  did n't do much of anything but stay high SHERR voice-over Joe shared a walk-up apartment in this building with two women  Toni Klein and her 15-year- old daughter Michelle . It was a house and a neighborhood of drifters. on camera But on the night of February 4th  Joe was planning to move out  so he came back here to pick up           Klein were murdered . Police found their bodies inside the apartment  a scene that was variously described by law enfforcement officials  ...
# ' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   coca_df.at[index, 'text'] = text
# RETURNING SMALL DATA FRAME. NO NAs.
# Number of website's texts incuded in data frame: 215736

# %%
# checkpoint (if needed)

count = count_matches(df_sources, dict_text_websites)
# Out:
# Number of matches: ids both in dicitonary and source: 219337

# %% [markdown]
# ### Interesting! From 21593 websites in the dictionary 21582 make match in the source!

# %% [markdown]
# # 4. Saves data frame

# %%
df.to_csv('span_full_text_1k_words.csv')

# %%
df_3k.to_csv('span_full_text_3k_words.csv')
