# %%
import pandas as pd
import os

# %%
os.listdir(r"C:\Users\asarr\Documents\Projects\pol-cul-maps-latam\press freedom index\raw")
# Out:
# ['2005.csv',
#  '2006.csv',
#  '2007.csv',
#  '2008.csv',
#  '2009.csv',
#  '2010.csv',
#  '2012.csv',
#  '2013.csv',
#  '2014.csv',
#  '2015.csv']

# %%
test = pd.read_csv(r"C:\Users\asarr\Documents\Projects\pol-cul-maps-latam\press freedom index\raw\2015.csv", delimiter=";")

# %%
density = pd.read_csv(r"")
